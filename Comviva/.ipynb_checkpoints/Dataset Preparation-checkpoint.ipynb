# %% [markdown]
# ## Loading Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Required Files

# %% [markdown]
# - Whether a customer agrees to the term-deposit or not is based on various factors like job, education, loan details, socio-economic details, etc.
# - Hence, all the files consisting of those details are loaded.

# %%
df_customer_details = pd.read_csv('Customer_and_bank details_p1.csv')
df_social_economic = pd.read_csv('Customer_social_economic_data_p1.csv')
df_campaign_details = pd.read_csv('Customer_campaign_details_p1.csv')
df_response_data = pd.read_csv('Customer_Response_data_p1.csv')

# %% [markdown]
# ## Merging The Dataframes

# %% [markdown]
# - The details are present in separate files.
# - To ease operations, we merge them into a single dataframe.
# - The 'Customer_id' column is common in all 4 dataframes.
# - Hence, it is used as a key for merging, meaning all columns are merged corresponding to the 'Customer_id'.

# %%
# Merge datasets on 'Customer_id' (assuming it's the common key)
df_merged = df_customer_details \
    .merge(df_social_economic, on='Customer_id') \
    .merge(df_campaign_details, on='Customer_id') \
    .merge(df_response_data, on='Customer_id')

# %% [markdown]
# ## Printing The Dataframe

# %%
df_merged
# Out:
#        Customer_id  age          job  marital            education  default  \
# 0                1   56     services  married          high.school       no
# 1                2   45     services  married             basic.9y  unknown
# 2                3   59       admin.  married  professional.course       no
# 3                4   41  blue-collar  married              unknown  unknown
# 4                5   24   technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079        37080   73      retired  married  professional.course       no
# 37080        37081   46  blue-collar  married  professional.course       no
# 37081        37082   56      retired  married    university.degree       no
# 37082        37083   44   technician  married  professional.course       no
# 37083        37084   74      retired  married  professional.course       no
#
#       housing loan Region_Code State_Code  ... nr.employed    contact  month  \
# 0          no  yes           3         S1  ...      5191.0  telephone    may
# 1          no   no           3         S1  ...      5191.0  telephone    may
# 2          no   no           4         S2  ...      5191.0  telephone    may
# 3          no   no           3         S3  ...      5191.0  telephone    may
# 4         yes   no           3         S3  ...      5191.0  telephone    may
# ...       ...  ...         ...        ...  ...         ...        ...    ...
# 37079     yes   no           2        S16  ...      4963.6   cellular    nov
# 37080      no   no           2        S16  ...      4963.6   cellular    nov
# 37081     yes   no           2        S16  ...      4963.6   cellular    nov
# 37082      no   no           4        S17  ...      4963.6   cellular    nov
# 37083     yes   no           1         S6  ...      4963.6   cellular    nov
#
#        day_of_week  duration  campaign pdays previous     poutcome    y
# 0              mon       307         1   999        0  nonexistent   no
# 1              mon       198         1   999        0  nonexistent   no
# 2              mon       139         1   999        0  nonexistent   no
# 3              mon       217         1   999        0  nonexistent   no
# 4              mon       380         1   999        0  nonexistent   no
# ...            ...       ...       ...   ...      ...          ...  ...
# 37079          fri       334         1   999        0  nonexistent  yes
# 37080          fri       383         1   999        0  nonexistent   no
# 37081          fri       189         2   999        0  nonexistent   no
# 37082          fri       442         1   999        0  nonexistent  yes
# 37083          fri       239         3   999        1      failure   no
#
# [37084 rows x 25 columns]

# %% [markdown]
# ## Printing The Datatype Of Each Column

# %%
df_merged.dtypes
# Out:
# Customer_id         int64
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# Region_Code        object
# State_Code         object
# City_Code          object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# y                  object
# dtype: object

# %% [markdown]
# - Region_Code, State_Code and City_Code do not give us any information.
# - The dataset would be more meaningful if instead of codes, we had their names.
# - The names of region can be extracted from Region_code_master.csv file.
# - The names of states can be extracted from State_master.csv file.
# - The names of city can be extracted from City_master.csv file.

# %% [markdown]
# ## Loading The Code Master Files

# %% [markdown]
# - We load all the code master csv files and check their datatypes.
# - Merging can only be done if the datatype of common columns in both csv files is same.

# %%
# Loading the Region_code_master.csv file
region_master = pd.read_csv('Region_code_master.csv')
region_master.dtypes
# Out:
# Region_Name    object
# Region_Code     int64
# dtype: object

# %%
# Checking if there are any values which are present in the region_master but not in df_merged
print("Unique values in the 'Region_Code' column of df_merged: ", df_merged['Region_Code'].unique())
print("Unique values in the 'Region_Code' column of region_master: ", region_master['Region_Code'].unique())
# Out:
# Unique values in the 'Region_Code' column of df_merged:  ['3' '4' 'Na' '1' '2']
# Unique values in the 'Region_Code' column of region_master:  [1 2 3 4 5]

# %% [markdown]
# Here, we see that 'Na' value is not present in region_master

# %%
# Loading the State_Master.csv file
state_master = pd.read_csv('State_Master.csv')
state_master.dtypes
# Out:
# State_Code     object
# State_Name     object
# Region_Code     int64
# dtype: object

# %%
# Extract unique state codes from df_merged and state_master
dataset_codes = set(df_merged['State_Code'].unique())
state_master_codes = set(df_merged['State_Code'].unique())

# Find state codes in df_merged that are not in state_master
unmatched_codes = dataset_codes - state_master_codes

if unmatched_codes:
    print("These state codes in dataset are not found in state_master:")
    print(unmatched_codes)
else:
    print("All state codes in dataset are valid and found in state_master.")
# Out:
# All state codes in dataset are valid and found in state_master.

# %%
# Loading the State_Master.csv file
city_master = pd.read_csv('City_Master.csv')
city_master.dtypes
# Out:
# City_Code     object
# City_Name     object
# State_Code    object
# dtype: object

# %%
# Extract unique city codes from df_merged and city_master
dataset_codes = set(df_merged['City_Code'].unique())
city_master_codes = set(city_master['City_Code'].unique())

# Find city codes in dataset that are not in city_master
unmatched_codes = dataset_codes - city_master_codes

if unmatched_codes:
    print("These city codes in dataset are not found in city_master:")
    print(unmatched_codes)
else:
    print("All city codes in dataset are valid and found in city_master.")
# Out:
# All city codes in dataset are valid and found in city_master.

# %% [markdown]
# - Since, datatype of Region_Code in df_merged is 'object' and that of Region_Code in region_master is 'int64', merging can't be made directly.
# - Moreover, Region_Code in df_merged has null values but State_Code and City_Code do not.
# - Hence, we will first merge the state and city names.

# %% [markdown]
# ## Merging State Names

# %% [markdown]
# - Since, State_Master.csv already has a Region_Code column, we can ignore the Region_Code column in df_merged and extract region names from state_master.

# %%
# Dropping 'Region_Code' 
df_merged.drop('Region_Code', axis=1, inplace=True)

# Perform the merge operation
df_merged = df_merged.merge(state_master, on='State_Code', how='left')
df_merged.drop('State_Code', axis=1, inplace=True)
df_merged
# Out:
#        Customer_id  age          job  marital            education  default  \
# 0                1   56     services  married          high.school       no
# 1                2   45     services  married             basic.9y  unknown
# 2                3   59       admin.  married  professional.course       no
# 3                4   41  blue-collar  married              unknown  unknown
# 4                5   24   technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079        37080   73      retired  married  professional.course       no
# 37080        37081   46  blue-collar  married  professional.course       no
# 37081        37082   56      retired  married    university.degree       no
# 37082        37083   44   technician  married  professional.course       no
# 37083        37084   74      retired  married  professional.course       no
#
#       housing loan City_Code  emp.var.rate  ...  month  day_of_week  duration  \
# 0          no  yes        C1           1.1  ...    may          mon       307
# 1          no   no        C1           1.1  ...    may          mon       198
# 2          no   no        C2           1.1  ...    may          mon       139
# 3          no   no        C3           1.1  ...    may          mon       217
# 4         yes   no        C3           1.1  ...    may          mon       380
# ...       ...  ...       ...           ...  ...    ...          ...       ...
# 37079     yes   no       C21          -1.1  ...    nov          fri       334
# 37080      no   no       C21          -1.1  ...    nov          fri       383
# 37081     yes   no       C21          -1.1  ...    nov          fri       189
# 37082      no   no       C49          -1.1  ...    nov          fri       442
# 37083     yes   no      C113          -1.1  ...    nov          fri       239
#
#        campaign pdays previous     poutcome    y  State_Name  Region_Code
# 0             1   999        0  nonexistent   no    Kentucky            3
# 1             1   999        0  nonexistent   no    Kentucky            3
# 2             1   999        0  nonexistent   no  California            4
# 3             1   999        0  nonexistent   no     Florida            3
# 4             1   999        0  nonexistent   no     Florida            3
# ...         ...   ...      ...          ...  ...         ...          ...
# 37079         1   999        0  nonexistent  yes    New York            2
# 37080         1   999        0  nonexistent   no    New York            2
# 37081         2   999        0  nonexistent   no    New York            2
# 37082         1   999        0  nonexistent  yes     Arizona            4
# 37083         3   999        1      failure   no       Texas            1
#
# [37084 rows x 25 columns]

# %% [markdown]
# ## Merging City Names

# %%
# Dropping 'State_Code' of df_merged
city_master.drop('State_Code', axis=1, inplace=True)

# Performing the merge operation
df_merged = df_merged.merge(city_master, on='City_Code', how='left')
df_merged.drop('City_Code', axis=1, inplace=True)
df_merged
# Out:
#        Customer_id  age          job  marital            education  default  \
# 0                1   56     services  married          high.school       no
# 1                2   45     services  married             basic.9y  unknown
# 2                3   59       admin.  married  professional.course       no
# 3                4   41  blue-collar  married              unknown  unknown
# 4                5   24   technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079        37080   73      retired  married  professional.course       no
# 37080        37081   46  blue-collar  married  professional.course       no
# 37081        37082   56      retired  married    university.degree       no
# 37082        37083   44   technician  married  professional.course       no
# 37083        37084   74      retired  married  professional.course       no
#
#       housing loan  emp.var.rate  cons.price.idx  ...  day_of_week  duration  \
# 0          no  yes           1.1          93.994  ...          mon       307
# 1          no   no           1.1          93.994  ...          mon       198
# 2          no   no           1.1          93.994  ...          mon       139
# 3          no   no           1.1          93.994  ...          mon       217
# 4         yes   no           1.1          93.994  ...          mon       380
# ...       ...  ...           ...             ...  ...          ...       ...
# 37079     yes   no          -1.1          94.767  ...          fri       334
# 37080      no   no          -1.1          94.767  ...          fri       383
# 37081     yes   no          -1.1          94.767  ...          fri       189
# 37082      no   no          -1.1          94.767  ...          fri       442
# 37083     yes   no          -1.1          94.767  ...          fri       239
#
#        campaign pdays previous     poutcome    y  State_Name  Region_Code  \
# 0             1   999        0  nonexistent   no    Kentucky            3
# 1             1   999        0  nonexistent   no    Kentucky            3
# 2             1   999        0  nonexistent   no  California            4
# 3             1   999        0  nonexistent   no     Florida            3
# 4             1   999        0  nonexistent   no     Florida            3
# ...         ...   ...      ...          ...  ...         ...          ...
# 37079         1   999        0  nonexistent  yes    New York            2
# 37080         1   999        0  nonexistent   no    New York            2
# 37081         2   999        0  nonexistent   no    New York            2
# 37082         1   999        0  nonexistent  yes     Arizona            4
# 37083         3   999        1      failure   no       Texas            1
#
#              City_Name
# 0            Henderson
# 1            Henderson
# 2          Los Angeles
# 3      Fort Lauderdale
# 4      Fort Lauderdale
# ...                ...
# 37079    New York City
# 37080    New York City
# 37081    New York City
# 37082       Scottsdale
# 37083         Amarillo
#
# [37084 rows x 25 columns]

# %% [markdown]
# ## Merging Region Names With Dataset

# %%
df_merged = df_merged.merge(region_master, on='Region_Code', how='left')
df_merged.drop('Region_Code', axis=1, inplace=True)
df_merged
# Out:
#        Customer_id  age          job  marital            education  default  \
# 0                1   56     services  married          high.school       no
# 1                2   45     services  married             basic.9y  unknown
# 2                3   59       admin.  married  professional.course       no
# 3                4   41  blue-collar  married              unknown  unknown
# 4                5   24   technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079        37080   73      retired  married  professional.course       no
# 37080        37081   46  blue-collar  married  professional.course       no
# 37081        37082   56      retired  married    university.degree       no
# 37082        37083   44   technician  married  professional.course       no
# 37083        37084   74      retired  married  professional.course       no
#
#       housing loan  emp.var.rate  cons.price.idx  ...  day_of_week  duration  \
# 0          no  yes           1.1          93.994  ...          mon       307
# 1          no   no           1.1          93.994  ...          mon       198
# 2          no   no           1.1          93.994  ...          mon       139
# 3          no   no           1.1          93.994  ...          mon       217
# 4         yes   no           1.1          93.994  ...          mon       380
# ...       ...  ...           ...             ...  ...          ...       ...
# 37079     yes   no          -1.1          94.767  ...          fri       334
# 37080      no   no          -1.1          94.767  ...          fri       383
# 37081     yes   no          -1.1          94.767  ...          fri       189
# 37082      no   no          -1.1          94.767  ...          fri       442
# 37083     yes   no          -1.1          94.767  ...          fri       239
#
#        campaign pdays previous     poutcome    y  State_Name        City_Name  \
# 0             1   999        0  nonexistent   no    Kentucky        Henderson
# 1             1   999        0  nonexistent   no    Kentucky        Henderson
# 2             1   999        0  nonexistent   no  California      Los Angeles
# 3             1   999        0  nonexistent   no     Florida  Fort Lauderdale
# 4             1   999        0  nonexistent   no     Florida  Fort Lauderdale
# ...         ...   ...      ...          ...  ...         ...              ...
# 37079         1   999        0  nonexistent  yes    New York    New York City
# 37080         1   999        0  nonexistent   no    New York    New York City
# 37081         2   999        0  nonexistent   no    New York    New York City
# 37082         1   999        0  nonexistent  yes     Arizona       Scottsdale
# 37083         3   999        1      failure   no       Texas         Amarillo
#
#        Region_Name
# 0            South
# 1            South
# 2             West
# 3            South
# 4            South
# ...            ...
# 37079         East
# 37080         East
# 37081         East
# 37082         West
# 37083      Central
#
# [37084 rows x 25 columns]

# %% [markdown]
# ## Rearranging Columns In Datasets

# %%
new_order = ['Customer_id', 'age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'City_Name', 'State_Name', 'Region_Name', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y']
df_merged = df_merged[new_order]
df_merged
# Out:
#        Customer_id  age          job  marital            education  default  \
# 0                1   56     services  married          high.school       no
# 1                2   45     services  married             basic.9y  unknown
# 2                3   59       admin.  married  professional.course       no
# 3                4   41  blue-collar  married              unknown  unknown
# 4                5   24   technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079        37080   73      retired  married  professional.course       no
# 37080        37081   46  blue-collar  married  professional.course       no
# 37081        37082   56      retired  married    university.degree       no
# 37082        37083   44   technician  married  professional.course       no
# 37083        37084   74      retired  married  professional.course       no
#
#       housing loan        City_Name  State_Name  ... nr.employed    contact  \
# 0          no  yes        Henderson    Kentucky  ...      5191.0  telephone
# 1          no   no        Henderson    Kentucky  ...      5191.0  telephone
# 2          no   no      Los Angeles  California  ...      5191.0  telephone
# 3          no   no  Fort Lauderdale     Florida  ...      5191.0  telephone
# 4         yes   no  Fort Lauderdale     Florida  ...      5191.0  telephone
# ...       ...  ...              ...         ...  ...         ...        ...
# 37079     yes   no    New York City    New York  ...      4963.6   cellular
# 37080      no   no    New York City    New York  ...      4963.6   cellular
# 37081     yes   no    New York City    New York  ...      4963.6   cellular
# 37082      no   no       Scottsdale     Arizona  ...      4963.6   cellular
# 37083     yes   no         Amarillo       Texas  ...      4963.6   cellular
#
#        month  day_of_week  duration  campaign pdays previous     poutcome    y
# 0        may          mon       307         1   999        0  nonexistent   no
# 1        may          mon       198         1   999        0  nonexistent   no
# 2        may          mon       139         1   999        0  nonexistent   no
# 3        may          mon       217         1   999        0  nonexistent   no
# 4        may          mon       380         1   999        0  nonexistent   no
# ...      ...          ...       ...       ...   ...      ...          ...  ...
# 37079    nov          fri       334         1   999        0  nonexistent  yes
# 37080    nov          fri       383         1   999        0  nonexistent   no
# 37081    nov          fri       189         2   999        0  nonexistent   no
# 37082    nov          fri       442         1   999        0  nonexistent  yes
# 37083    nov          fri       239         3   999        1      failure   no
#
# [37084 rows x 25 columns]

# %% [markdown]
# ## Saving The Dataframe To dataset.csv

# %%
df_merged.to_csv('dataset.csv', index=False)
